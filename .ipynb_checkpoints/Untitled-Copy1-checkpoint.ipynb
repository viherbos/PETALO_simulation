# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib nbagg
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append("./SimLib")
import HF_files as HF

# %%
A = HF.hdf_access("/home/viherbos/DAQ_DATA/NEUTRINOS/CONT_RING","p_FR_infinity_0.h5")

# %%
out=A.read()

# %%
datos=out[0]

# %%
np.sum(datos[0,:])
# Out:
# 2478

# %%
B = HF.hdf_access("/home/viherbos/DAQ_DATA/NEUTRINOS/CONT_RING","daq_out.h5")

# %%
out_daq = B.read()

# %%
event = 5

# %%
dif=out_daq[0][event,:]-datos[event,:]
print np.sum(dif<0)
plt.plot(out_daq[0][event,:])
plt.plot(datos[event,:])
plt.plot(dif*20)
# Out:
# 456
# <img src="data:image/png;base64,..." width="640">
