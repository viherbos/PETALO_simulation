# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib nbagg
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append("./SimLib")
import HF_translator as HFT
import HF_files as HFF

# %%
A = HFT.HF("/home/viherbos/DAQ_DATA/NEUTRINOS","LXe_SiPM9mm2_xyz5cm_0.pet.h5","prueba")

# %%
A.read()

# %%
x=A.sensors_t[:,1]
y=A.sensors_t[:,2]
z=A.sensors_t[:,3]
s=A.sensors_t[:,0]

fig, ax0 = plt.subplots()
ax0.scatter(x, y)

for i, txt in enumerate(s):
    if (int(txt)>=1000 and int(txt)<1064):
        ax0.annotate(str(txt)+"("+str(z[i])+")", (x[i],y[i]))

fig, ax1 = plt.subplots()
ax1.scatter(x, y)
for i, txt in enumerate(s):
    if (int(txt)>=1064 and int(txt)<1128):
        ax1.annotate(str(txt)+"("+str(z[i])+")", (x[i],y[i]))

fig, ax2 = plt.subplots()
ax2.scatter(x, y)
for i, txt in enumerate(s):
    if (int(txt)>=2000 and int(txt)<2064):
        ax2.annotate(str(txt)+"("+str(z[i])+")", (x[i],y[i]))

fig, ax3 = plt.subplots()
ax3.scatter(x, y)
for i, txt in enumerate(s):
    if (int(txt)>=2064 and int(txt)<2128):
        ax3.annotate(str(txt)+"("+str(z[i])+")", (x[i],y[i]))

        
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
A.process()
# Out:
# EVENT 0 processed
# EVENT 1 processed
# EVENT 2 processed
# EVENT 3 processed
# EVENT 4 processed
# EVENT 5 processed
# EVENT 6 processed
# EVENT 7 processed
# EVENT 8 processed
# EVENT 9 processed
# EVENT 10 processed
# EVENT 11 processed
# EVENT 12 processed
# EVENT 13 processed
# EVENT 14 processed
# EVENT 15 processed
# EVENT 16 processed
# EVENT 17 processed
# EVENT 18 processed
# EVENT 19 processed
# EVENT 20 processed
# EVENT 21 processed
# EVENT 22 processed
# EVENT 23 processed
# EVENT 24 processed
# EVENT 25 processed
# EVENT 26 processed
# EVENT 27 processed
# EVENT 28 processed
# EVENT 29 processed
# EVENT 30 processed
# EVENT 31 processed
# EVENT 32 processed
# EVENT 33 processed
# EVENT 34 processed
# EVENT 35 processed
# EVENT 36 processed
# EVENT 37 processed
# EVENT 38 processed
# EVENT 39 processed
# EVENT 40 processed
# EVENT 41 processed
# EVENT 42 processed
# EVENT 43 processed
# EVENT 44 processed
# EVENT 45 processed
# EVENT 46 processed
# EVENT 47 processed
# ...

# %%
A.write()
# Out:
# [1000 1001 1002 1003 1004 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014
#  1015 1016 1017 1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028 1029
#  1030 1031 1032 1033 1034 1035 1036 1037 1038 1039 1040 1041 1042 1043 1044
#  1045 1046 1047 1048 1049 1050 1051 1052 1053 1054 1055 1056 1057 1058 1059
#  1060 1061 1062 1063 1064 1065 1066 1067 1068 1069 1070 1071 1072 1073 1074
#  1075 1076 1077 1078 1079 1080 1081 1082 1083 1084 1085 1086 1087 1088 1089
#  1090 1091 1092 1093 1094 1095 1096 1097 1098 1099 1100 1101 1102 1103 1104
#  1105 1106 1107 1108 1109 1110 1111 1112 1113 1114 1115 1116 1117 1118 1119
#  1120 1121 1122 1123 1124 1125 1126 1127 2000 2001 2002 2003 2004 2005 2006
#  2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021
#  2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2032 2033 2034 2035 2036
#  2037 2038 2039 2040 2041 2042 2043 2044 2045 2046 2047 2048 2049 2050 2051
# ...
